# %%
import time
start_time = time.time()

import numpy as np
import pandas as pd
import math as mt

from nltk.stem.porter import *
stemmer = PorterStemmer()

# load csv data
df_train = pd.read_csv('./input/train_subset.csv', encoding="ISO-8859-1")

# %%
#Preprocessing
from nltk.corpus import stopwords

def preprocess(row):
    searchterm = row["search_term"]
    return len(searchterm)

def removeStop(row):
    phraseArray = row["search_term"].split()
    stops = set(stopwords.words("english"))
    nonstopwords = [w for w in phraseArray if not w in stops]
    return len(nonstopwords)

def countWords(row):
    phaseArray = row["search_term"].split()
    return len(phaseArray)

df_train['char_count'] = df_train.apply(preprocess, axis=1)
df_train['no_stopwords'] = df_train.apply(removeStop, axis=1)
df_train['word_count'] = df_train.apply(countWords, axis=1)

print('All words')
print(df_train[['relevance', 'char_count']].corr(method='pearson'))
print('\nNo stopwords')
print(df_train[['relevance', 'no_stopwords']].corr(method='pearson'))
print('\nWord counts')
print(df_train[['relevance', 'word_count']].corr(method='pearson'))

#Strongest relationship is without stopwords
# Out:
# All words
#             relevance  char_count
# relevance    1.000000   -0.001533
# char_count  -0.001533    1.000000
#
# No stopwords
#               no_stopwords  relevance
# no_stopwords      1.000000  -0.032249
# relevance        -0.032249   1.000000
#
# Word counts
#             relevance  word_count
# relevance    1.000000   -0.004733
# word_count  -0.004733    1.000000

# %%
from nltk.stem.porter import *
stemmer = PorterStemmer()

shingle_size = 3
def cleanAndShingle(s, k = shingle_size):
    #remove stop words
    s = s.lower()
    #print(s)
    phraseArray = s.split()
    stops = set(stopwords.words("english"))
    stops = set([])
    #remove stopwords
    nonstopwords = [w for w in phraseArray if not w in stops]
    #remove meassure units
    units = set(["in.", "ft.", "&amp;"])
    nounits = [word for word in nonstopwords if not word in units]
    s = " ".join([stemmer.stem(word) for word in nounits])
    s = re.sub('[*]', 'x', s)
    s = re.sub('[by]', 'x', s)
    return [s[i:i + k] for i in range(len(s) - k + 1)]

# %%
df_train['search_shingles'] = df_train['search_term'].map(cleanAndShingle)
df_train['title_shingles'] = df_train['product_title'].map(cleanAndShingle)

# %%
def jaccard(row):
    search_shingles = set(row["search_shingles"])
    title_shingles = set(row["title_shingles"])
    
    union = search_shingles | title_shingles
    intersection = search_shingles & title_shingles
    
    return (len(intersection)/len(union))

df_train['jaccard'] = df_train.apply(jaccard, axis=1)
df_train[["search_shingles", "title_shingles", "jaccard"]]
# Out:
#                                       search_shingles  \
# 0   [ang, ngl, gl , l x,  xr, xra, rac, ack, cke, ...
# 1                 [l x,  xr, xra, rac, ack, cke, ket]
# 2                 [dec, eck, ck , k o,  ov, ove, ver]
# 3   [rai, ain, in , n s,  sh, sho, how, owe, wer, ...
# 4   [sho, how, owe, wer, er , r o,  on, onl, nli, ...
# 5       [con, onv, nve, vec, ect, ct , t o,  ot, otr]
# 6   [mic, icr, cro, row, owa, wav, av , v o,  ov, ...
# 7                      [mic, icr, cro, row, owa, wav]
# 8       [eme, mer, erg, rg , g l,  li, lig, igh, ght]
# 9                           [mdf, df , f 3,  3/, 3/4]
# 10      [ste, tee, eel, el , l s,  st, sta, tak, ake]
# 11  [xri, rig, igg, gg , g a,  an, and, nd , d s, ...
# 12  [xri, rig, igg, gg , g a,  an, and, nd , d s, ...
# 13                               [ga , a m,  mo, mow]
# 14      [hon, ond, nda, da , a m,  mo, mow, owe, wer]
# 15  [xri, rig, igg, gg , g a,  an, and, nd , d s, ...
# 16  [ham, amp, mpt, pto, ton, on , n x,  xa, xax, ...
# 17                               [dis, isp, spo, pos]
# 18  [gri, ril, ill, ll , l g,  ga, gaz, aze, zex, ...
# 19           [doo, oor, or , r g,  gu, gua, uar, ard]
# 20  [met, eta, tal, al , l p,  pl, pla, lat, ate, ...
# 21  [rad, adi, dia, iat, at , t g,  gr, gra, rat, ...
# 22  [win, ind, ndo, dow, ow , w s,  sc, scr, cre, ...
# 23  [1x1, x1 , 1 r,  ra, rai, ail, il , l d,  de, ...
# 24  [4x8, x8 , 8 x,  xe, xea, ead, adx, dxo, xoa, ...
# 25  [4x8, x8 , 8 x,  xe, xea, ead, ad , d p,  pa, ...
# 26                          [mdf, df , f 4,  4x, 4x8]
# 27  [wai, ain, ins, nsc, sco, cot, ot , t c,  ch, ...
# 28  [wai, ain, ins, nsc, sco, cot, ot , t p,  pl, ...
# 29  [law, awn, wn , n s,  sp, spr, prk, rki, kin, ...
# ..                                                ...
# 70  [sto, tov, ove, ve , e a,  an, and, nd , d m, ...
# 71  [ven, ent, ntl, tle, les, ess, ss , s g,  ga, ...
# 72  [ame, mer, eri, ric, ica, can, an , n s,  st, ...
# 73  [cad, ade, det, et , t 3,  3 , 3 i,  in, ins, ...
# 74                          [gra, rax, axs, xso, son]
# 75                          [6 s,  st, ste, tel, ell]
# 76  [fec, ece, ce , e p,  po, pos, ost, st , t m, ...
# 77  [gre, ree, een, en , n p,  pa, pai, ain, int, ...
# 78  [con, onc, ncr, cre, ret, et , t f,  fo, for, ...
# 79  [gre, ree, een, en , n p,  po, pop, op , p r, ...
# 80                                         [pos, ost]
# 81  [wir, ire, re , e f,  fe, fen, enc, nc , c 6, ...
# 82  [xol, olt, lt , t 1,  1/, 1/2, /2 , 2 i,  in, ...
# 83      [met, eta, tal, al , l s,  sh, she, hee, eet]
# 84      [she, hee, eet, et , t m,  me, met, eta, tal]
# 85  [ela, las, ast, sto, tom, ome, mer, er , r r, ...
# 86  [out, utd, tdo, doo, oor, or , r d,  di, din, ...
# 87  [cus, ush, shi, hio, ion, on , n o,  ou, out, ...
# 88  [ham, amp, mpt, pto, ton, on , n x,  xa, xax, ...
# 89  [out, utd, tdo, doo, oor, orf, rfu, fur, urn, ...
# 90                     [wir, ire, rem, eme, mes, esh]
# 91           [fro, ron, ont, nt , t d,  do, doo, oor]
# 92  [pre, reh, ehu, hun, ung, ng , g s,  st, ste, ...
# 93  [sta, tan, anl, nle, lex, ex , x d,  do, doo, ...
# 94  [kin, ing, ngs, gsl, sle, lex, ex , x m,  mo, ...
# 95  [kit, itc, tch, che, hen, en , n s,  si, sin, ...
# 96  [pri, ric, ice, cep, epf, pfi, fis, ist, st , ...
# 97  [soa, oap, ap , p d,  di, dis, isp, spe, pen, ...
# 98  [soa, oap, ap , p d,  di, dis, isp, spe, pen, ...
# 99      [sta, tan, anl, nli, li , i d,  do, doo, oor]
#
#                                        title_shingles   jaccard
# 0   [sim, imp, mps, pso, son, on , n s,  st, str, ...  0.055556
# 1   [sim, imp, mps, pso, son, on , n s,  st, str, ...  0.000000
# 2   [xeh, ehr, hr , r p,  pr, pre, rem, emi, miu, ...  0.027778
# 3   [del, elt, lta, ta , a v,  ve, ver, ero, ro , ...  0.088608
# 4   [del, elt, lta, ta , a v,  ve, ver, ero, ro , ...  0.222222
# 5   [whi, hir, irl, rlp, lpo, poo, ool, ol , l 1, ...  0.072289
# 6   [whi, hir, irl, rlp, lpo, poo, ool, ol , l 1, ...  0.142857
# 7   [whi, hir, irl, rlp, lpo, poo, ool, ol , l 1, ...  0.075000
# 8   [lit, ith, tho, hon, oni, nia, ia , a l,  li, ...  0.150943
# 9   [hou, ous, us , s o,  of, of , f f,  fa, far, ...  0.111111
# 10  [val, all, lle, lex, ex , x v,  vi, vie, iew, ...  0.116279
# 11  [tor, oro, ro , o p,  pe, per, ers, rso, son, ...  0.234043
# 12  [tor, oro, ro , o p,  pe, per, ers, rso, son, ...  0.234043
# 13  [tor, oro, ro , o p,  pe, per, ers, rso, son, ...  0.033333
# 14  [tor, oro, ro , o p,  pe, per, ers, rso, son, ...  0.042553
# 15  [tor, oro, ro , o p,  pe, per, ers, rso, son, ...  0.234043
# 16  [ham, amp, mpt, pto, ton, on , n x,  xa, xax, ...  0.223684
# 17  [ins, nsi, sin, ink, nke, ker, er , r s,  si, ...  0.093023
# 18  [sun, unj, njo, jox, ox , x c,  ca, cal, ala, ...  0.204082
# 19  [md , d x,  xu, xui, uil, ild, ld , d p,  pr, ...  0.000000
# 20  [md , d x,  xu, xui, uil, ild, ld , d p,  pr, ...  0.028169
# 21  [md , d x,  xu, xui, uil, ild, ld , d p,  pr, ...  0.000000
# 22  [md , d x,  xu, xui, uil, ild, ld , d p,  pr, ...  0.000000
# 23  [hou, ous, us , s o,  of, of , f f,  fa, far, ...  0.013333
# 24  [hou, ous, us , s o,  of, of , f f,  fa, far, ...  0.055556
# 25  [hou, ous, us , s o,  of, of , f f,  fa, far, ...  0.059701
# 26  [hou, ous, us , s o,  of, of , f f,  fa, far, ...  0.032258
# 27  [hou, ous, us , s o,  of, of , f f,  fa, far, ...  0.101449
# 28  [hou, ous, us , s o,  of, of , f f,  fa, far, ...  0.166667
# 29  [180, 804, 04 , 4 d,  du, dua, ual, al , l s, ...  0.037736
# ..                                                ...       ...
# 70  [emx, mxe, xer, erg, rgl, glo, low, ow , w 2, ...  0.058824
# 71  [emx, mxe, xer, erg, rgl, glo, low, ow , w 2, ...  0.132353
# 72  [ame, mer, eri, ric, ica, can, an , n s,  st, ...  0.312500
# 73  [ame, mer, eri, ric, ica, can, an , n s,  st, ...  0.153846
# 74  [sum, umn, mne, ner, er , r s,  st, str, tre, ...  0.081967
# 75  [hdx, dx , x 6,  6 , 6 h,  he, hea, eav, avi, ...  0.047619
# 76  [hdx, dx , x 6,  6 , 6 h,  he, hea, eav, avi, ...  0.040000
# 77  [hdx, dx , x 6,  6 , 6 h,  he, hea, eav, avi, ...  0.208333
# 78  [qui, uik, ikr, kre, ret, et , t 8,  80, 80 , ...  0.150000
# 79  [hdx, dx , x 6,  6 , 6 h,  he, hea, eav, avi, ...  0.106383
# 80  [hdx, dx , x 6,  6 , 6 h,  he, hea, eav, avi, ...  0.051282
# 81  [hdx, dx , x 6,  6 , 6 h,  he, hea, eav, avi, ...  0.018182
# 82  [cro, row, own, wn , n x,  xo, xol, olt, lt , ...  0.200000
# 83  [cro, row, own, wn , n x,  xo, xol, olt, lt , ...  0.173913
# 84  [cro, row, own, wn , n x,  xo, xol, olt, lt , ...  0.148936
# 85  [hen, enr, nri, ri , i 5,  58, 587, 87 , 7 4, ...  0.190476
# 86  [ham, amp, mpt, pto, ton, on , n x,  xa, xax, ...  0.042857
# 87  [ham, amp, mpt, pto, ton, on , n x,  xa, xax, ...  0.100000
# 88  [ham, amp, mpt, pto, ton, on , n x,  xa, xax, ...  0.197531
# 89  [ham, amp, mpt, pto, ton, on , n x,  xa, xax, ...  0.000000
# 90  [60 , 0 x,  x , x 1,  15, 150, 50 , 0 1,  10, ...  0.190476
# 91  [sta, tan, anl, nle, lex, ex , x d,  do, doo, ...  0.112676
# 92  [sta, tan, anl, nle, lex, ex , x d,  do, doo, ...  0.191781
# 93  [sta, tan, anl, nle, lex, ex , x d,  do, doo, ...  0.140845
# 94  [moe, oen, en , n e,  es, ess, ssi, si , i s, ...  0.158416
# 95  [moe, oen, en , n e,  es, ess, ssi, si , i s, ...  0.147368
# 96  [moe, oen, en , n e,  es, ess, ssi, si , i s, ...  0.153846
# 97  [moe, oen, en , n e,  es, ess, ssi, si , i s, ...  0.170213
# 98  [moe, oen, en , n e,  es, ess, ssi, si , i s, ...  0.170213
# 99  [sta, tan, anl, nle, lex, ex , x d,  do, doo, ...  0.081081
#
# [100 rows x 3 columns]

# %%
print(df_train[['relevance', 'jaccard']].corr(method='pearson'))
# Out:
#            relevance   jaccard
# relevance   1.000000  0.332853
# jaccard     0.332853  1.000000

# %%
df_train
# Out:
#      id  product_uid                                      product_title  \
# 0     2       100001                  Simpson Strong-Tie 12-Gauge Angle
# 1     3       100001                  Simpson Strong-Tie 12-Gauge Angle
# 2     9       100002  BEHR Premium Textured DeckOver 1-gal. #SC-141 ...
# 3    16       100005  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 4    17       100005  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 5    18       100006  Whirlpool 1.9 cu. ft. Over the Range Convectio...
# 6    20       100006  Whirlpool 1.9 cu. ft. Over the Range Convectio...
# 7    21       100006  Whirlpool 1.9 cu. ft. Over the Range Convectio...
# 8    23       100007  Lithonia Lighting Quantum 2-Light Black LED Em...
# 9    27       100009  House of Fara 3/4 in. x 3 in. x 8 ft. MDF Flut...
# 10   34       100010       Valley View Industries Metal Stakes (4-Pack)
# 11   35       100011  Toro Personal Pace Recycler 22 in. Variable Sp...
# 12   36       100011  Toro Personal Pace Recycler 22 in. Variable Sp...
# 13   37       100011  Toro Personal Pace Recycler 22 in. Variable Sp...
# 14   38       100011  Toro Personal Pace Recycler 22 in. Variable Sp...
# 15   39       100011  Toro Personal Pace Recycler 22 in. Variable Sp...
# 16   48       100012  Hampton Bay Caramel Simple Weave Bamboo Rollup...
# 17   51       100013  InSinkErator SinkTop Switch Single Outlet for ...
# 18   65       100016  Sunjoy Calais 8 ft. x 5 ft. x 8 ft. Steel Tile...
# 19   69       100017  MD Building Products 36 in. x 36 in. Cloverlea...
# 20   75       100017  MD Building Products 36 in. x 36 in. Cloverlea...
# 21   81       100017  MD Building Products 36 in. x 36 in. Cloverlea...
# 22   85       100017  MD Building Products 36 in. x 36 in. Cloverlea...
# 23   88       100019  House of Fara 8 Linear ft. MDF Overlapping Wai...
# 24   90       100019  House of Fara 8 Linear ft. MDF Overlapping Wai...
# 25   92       100019  House of Fara 8 Linear ft. MDF Overlapping Wai...
# 26  101       100019  House of Fara 8 Linear ft. MDF Overlapping Wai...
# 27  105       100019  House of Fara 8 Linear ft. MDF Overlapping Wai...
# 28  106       100019  House of Fara 8 Linear ft. MDF Overlapping Wai...
# 29  113       100021  1804 Dual Spray Half Pattern 4 in Pop-Up Spray...
# ..  ...          ...                                                ...
# 70  227       100039  Emberglow 25,000 BTU Vent-Free Dual Fuel Gas S...
# 71  233       100039  Emberglow 25,000 BTU Vent-Free Dual Fuel Gas S...
# 72  241       100042  American Standard Cadet 3 FloWise 2-piece 1.28...
# 73  245       100042  American Standard Cadet 3 FloWise 2-piece 1.28...
# 74  255       100045  Sumner Street Home Hardware Grayson 2-1/2 in. ...
# 75  257       100046    HDX 6 ft. Heavy Duty Steel Green Painted T-Post
# 76  259       100046    HDX 6 ft. Heavy Duty Steel Green Painted T-Post
# 77  261       100046    HDX 6 ft. Heavy Duty Steel Green Painted T-Post
# 78  262       100023           Quikrete 80 lb. Crack-Resistant Concrete
# 79  263       100046    HDX 6 ft. Heavy Duty Steel Green Painted T-Post
# 80  266       100046    HDX 6 ft. Heavy Duty Steel Green Painted T-Post
# 81  270       100046    HDX 6 ft. Heavy Duty Steel Green Painted T-Post
# 82  272       100047  Crown Bolt 24 in. x 1/2 in. x 12 in. Plain Met...
# 83  275       100047  Crown Bolt 24 in. x 1/2 in. x 12 in. Plain Met...
# 84  276       100047  Crown Bolt 24 in. x 1/2 in. x 12 in. Plain Met...
# 85  284       100049             Henry 587 4.75 Gal. White Roof Coating
# 86  290       100050  Hampton Bay Beverly Patio Dining Arm Chairs wi...
# 87  293       100051  Hampton Bay Spring Haven Brown All-Weather Wic...
# 88  294       100051  Hampton Bay Spring Haven Brown All-Weather Wic...
# 89  297       100051  Hampton Bay Spring Haven Brown All-Weather Wic...
# 90  305       100053                      60 in. x 150 ft. 10/10 Remesh
# 91  314       100054  Stanley Doors 36 in. x 80 in. Chatham 3/4 Lite...
# 92  318       100054  Stanley Doors 36 in. x 80 in. Chatham 3/4 Lite...
# 93  319       100054  Stanley Doors 36 in. x 80 in. Chatham 3/4 Lite...
# 94  323       100055  MOEN Essie Single-Handle Pull-Down Sprayer Kit...
# 95  327       100055  MOEN Essie Single-Handle Pull-Down Sprayer Kit...
# 96  331       100055  MOEN Essie Single-Handle Pull-Down Sprayer Kit...
# 97  334       100055  MOEN Essie Single-Handle Pull-Down Sprayer Kit...
# 98  335       100055  MOEN Essie Single-Handle Pull-Down Sprayer Kit...
# 99  336       100054  Stanley Doors 36 in. x 80 in. Chatham 3/4 Lite...
#
#                             search_term  relevance  char_count  no_stopwords  \
# 0                         angle bracket       3.00          13             2
# 1                             l bracket       2.50           9             2
# 2                             deck over       3.00           9             1
# 3                      rain shower head       2.33          16             3
# 4                    shower only faucet       2.67          18             2
# 5                        convection otr       3.00          14             2
# 6                  microwave over stove       2.67          20             2
# 7                            microwaves       3.00          10             1
# 8                       emergency light       2.67          15             2
# 9                               mdf 3/4       3.00           7             2
# 10                         steele stake       2.67          12             2
# 11       briggs and stratton lawn mower       3.00          30             4
# 12       briggs and stratton lawn mower       3.00          30             4
# 13                             gas mowe       3.00           8             2
# 14                          honda mower       2.00          11             2
# 15       briggs and stratton lawn mower       3.00          30             4
# 16   hampton bay chestnut pull up shade       2.67          34             5
# 17                             disposer       2.67           8             1
# 18                         grill gazebo       3.00          12             2
# 19                          door guards       1.00          11             2
# 20               metal plate cover gcfi       1.67          22             4
# 21                       radiator grate       2.33          14             2
# 22                      windows screens       2.33          15             2
# 23             1x1 rail decorative wood       1.33          24             4
# 24               4*8 beadboard paneling       2.67          22             3
# 25                  4x8 beaded paneling       2.33          19             3
# 26                              MDF 4x8       1.33           7             2
# 27                  wainscot chair rail       2.33          19             3
# 28              wainscot plank paneling       2.33          23             3
# 29                       lawn sprkinler       2.00          14             2
# ..                                  ...        ...         ...           ...
# 70                         stove and mi       2.33          12             2
# 71                   ventless gas stove       3.00          18             3
# 72  American Standard Bone round toliet       3.00          35             5
# 73            cadet 3 insulated in bone       2.33          25             4
# 74                              grayson       2.33           7             1
# 75                              6 stell       2.00           7             2
# 76                     fece posts metal       2.00          16             3
# 77             green painted pop rivets       2.33          24             4
# 78                   concrete for ponds       2.00          18             2
# 79                     green pop rivets       2.33          16             3
# 80                                 post       2.67           4             1
# 81               wire fencing 6 ft high       1.67          22             5
# 82                    bolt 1/2 in by 12       3.00          17             3
# 83                          metal sheet       2.33          11             2
# 84                          sheet metal       3.00          11             2
# 85             elastomeric roof coating       2.00          24             3
# 86                       outdoor dining       2.67          14             2
# 87               cushions outdoorlounge       3.00          22             2
# 88                   hampton bay spring       3.00          18             3
# 89                     outdoorfurniture       2.33          16             1
# 90                             wiremesh       3.00           8             1
# 91                          front doors       3.00          11             2
# 92                   prehung steel door       3.00          18             3
# 93                        stanley doors       2.67          13             2
# 94         kingsley moen kitchen faucet       2.33          28             4
# 95                  kitchen sink faucet       3.00          19             3
# 96     pricepfister kitchen faucet g135       2.00          32             4
# 97               soap dispenser kitchen       2.67          22             3
# 98               soap dispenser kitchen       2.66          22             3
# 99                         stanly doors       2.67          12             2
#
#     word_count                                    search_shingles  \
# 0            2  [ang, ngl, gl , l b,  br, bra, rac, ack, cke, ...
# 1            2                [l b,  br, bra, rac, ack, cke, ket]
# 2            2                [dec, eck, ck , k o,  ov, ove, ver]
# 3            3  [rai, ain, in , n s,  sh, sho, how, owe, wer, ...
# 4            3  [sho, how, owe, wer, er , r o,  on, onl, nli, ...
# 5            2      [con, onv, nve, vec, ect, ct , t o,  ot, otr]
# 6            3  [mic, icr, cro, row, owa, wav, av , v o,  ov, ...
# 7            1                     [mic, icr, cro, row, owa, wav]
# 8            2      [eme, mer, erg, rg , g l,  li, lig, igh, ght]
# 9            2                          [mdf, df , f 3,  3/, 3/4]
# 10           2      [ste, tee, eel, el , l s,  st, sta, tak, ake]
# 11           5  [bri, rig, igg, gg , g a,  an, and, nd , d s, ...
# 12           5  [bri, rig, igg, gg , g a,  an, and, nd , d s, ...
# 13           2                               [ga , a m,  mo, mow]
# 14           2      [hon, ond, nda, da , a m,  mo, mow, owe, wer]
# 15           5  [bri, rig, igg, gg , g a,  an, and, nd , d s, ...
# 16           6  [ham, amp, mpt, pto, ton, on , n b,  ba, bay, ...
# 17           1                               [dis, isp, spo, pos]
# 18           2  [gri, ril, ill, ll , l g,  ga, gaz, aze, zeb, ...
# 19           2           [doo, oor, or , r g,  gu, gua, uar, ard]
# 20           4  [met, eta, tal, al , l p,  pl, pla, lat, ate, ...
# 21           2  [rad, adi, dia, iat, at , t g,  gr, gra, rat, ...
# 22           2  [win, ind, ndo, dow, ow , w s,  sc, scr, cre, ...
# 23           4  [1x1, x1 , 1 r,  ra, rai, ail, il , l d,  de, ...
# 24           3  [4x8, x8 , 8 b,  be, bea, ead, adb, dbo, boa, ...
# 25           3  [4x8, x8 , 8 b,  be, bea, ead, ad , d p,  pa, ...
# 26           2                          [mdf, df , f 4,  4x, 4x8]
# 27           3  [wai, ain, ins, nsc, sco, cot, ot , t c,  ch, ...
# 28           3  [wai, ain, ins, nsc, sco, cot, ot , t p,  pl, ...
# 29           2  [law, awn, wn , n s,  sp, spr, prk, rki, kin, ...
# ..         ...                                                ...
# 70           3  [sto, tov, ove, ve , e a,  an, and, nd , d m, ...
# 71           3  [ven, ent, ntl, tle, les, ess, ss , s g,  ga, ...
# 72           5  [ame, mer, eri, ric, ica, can, an , n s,  st, ...
# 73           5  [cad, ade, det, et , t 3,  3 , 3 i,  in, ins, ...
# 74           1                          [gra, ray, ays, yso, son]
# 75           2                          [6 s,  st, ste, tel, ell]
# 76           3  [fec, ece, ce , e p,  po, pos, ost, st , t m, ...
# 77           4  [gre, ree, een, en , n p,  pa, pai, ain, int, ...
# 78           3  [con, onc, ncr, cre, ret, et , t f,  fo, for, ...
# 79           3  [gre, ree, een, en , n p,  po, pop, op , p r, ...
# 80           1                                         [pos, ost]
# 81           5  [wir, ire, re , e f,  fe, fen, enc, nc , c 6, ...
# 82           5  [bol, olt, lt , t 1,  1/, 1/2, /2 , 2 i,  in, ...
# 83           2      [met, eta, tal, al , l s,  sh, she, hee, eet]
# 84           2      [she, hee, eet, et , t m,  me, met, eta, tal]
# 85           3  [ela, las, ast, sto, tom, ome, mer, er , r r, ...
# 86           2  [out, utd, tdo, doo, oor, or , r d,  di, din, ...
# 87           2  [cus, ush, shi, hio, ion, on , n o,  ou, out, ...
# 88           3  [ham, amp, mpt, pto, ton, on , n b,  ba, bay, ...
# 89           1  [out, utd, tdo, doo, oor, orf, rfu, fur, urn, ...
# 90           1                     [wir, ire, rem, eme, mes, esh]
# 91           2           [fro, ron, ont, nt , t d,  do, doo, oor]
# 92           3  [pre, reh, ehu, hun, ung, ng , g s,  st, ste, ...
# 93           2  [sta, tan, anl, nle, ley, ey , y d,  do, doo, ...
# 94           4  [kin, ing, ngs, gsl, sle, ley, ey , y m,  mo, ...
# 95           3  [kit, itc, tch, che, hen, en , n s,  si, sin, ...
# 96           4  [pri, ric, ice, cep, epf, pfi, fis, ist, st , ...
# 97           3  [soa, oap, ap , p d,  di, dis, isp, spe, pen, ...
# 98           3  [soa, oap, ap , p d,  di, dis, isp, spe, pen, ...
# 99           2      [sta, tan, anl, nli, li , i d,  do, doo, oor]
#
#                                        title_shingles   jaccard
# 0   [sim, imp, mps, pso, son, on , n s,  st, str, ...  0.055556
# 1   [sim, imp, mps, pso, son, on , n s,  st, str, ...  0.000000
# 2   [beh, ehr, hr , r p,  pr, pre, rem, emi, miu, ...  0.027778
# 3   [del, elt, lta, ta , a v,  ve, ver, ero, ro , ...  0.088608
# 4   [del, elt, lta, ta , a v,  ve, ver, ero, ro , ...  0.222222
# 5   [whi, hir, irl, rlp, lpo, poo, ool, ol , l 1, ...  0.072289
# 6   [whi, hir, irl, rlp, lpo, poo, ool, ol , l 1, ...  0.142857
# 7   [whi, hir, irl, rlp, lpo, poo, ool, ol , l 1, ...  0.075000
# 8   [lit, ith, tho, hon, oni, nia, ia , a l,  li, ...  0.150943
# 9   [hou, ous, us , s o,  of, of , f f,  fa, far, ...  0.111111
# 10  [val, all, lle, ley, ey , y v,  vi, vie, iew, ...  0.116279
# 11  [tor, oro, ro , o p,  pe, per, ers, rso, son, ...  0.234043
# 12  [tor, oro, ro , o p,  pe, per, ers, rso, son, ...  0.234043
# 13  [tor, oro, ro , o p,  pe, per, ers, rso, son, ...  0.033333
# 14  [tor, oro, ro , o p,  pe, per, ers, rso, son, ...  0.042553
# 15  [tor, oro, ro , o p,  pe, per, ers, rso, son, ...  0.234043
# 16  [ham, amp, mpt, pto, ton, on , n b,  ba, bay, ...  0.223684
# 17  [ins, nsi, sin, ink, nke, ker, er , r s,  si, ...  0.093023
# 18  [sun, unj, njo, joy, oy , y c,  ca, cal, ala, ...  0.204082
# 19  [md , d b,  bu, bui, uil, ild, ld , d p,  pr, ...  0.000000
# 20  [md , d b,  bu, bui, uil, ild, ld , d p,  pr, ...  0.028169
# 21  [md , d b,  bu, bui, uil, ild, ld , d p,  pr, ...  0.000000
# 22  [md , d b,  bu, bui, uil, ild, ld , d p,  pr, ...  0.000000
# 23  [hou, ous, us , s o,  of, of , f f,  fa, far, ...  0.013333
# 24  [hou, ous, us , s o,  of, of , f f,  fa, far, ...  0.055556
# 25  [hou, ous, us , s o,  of, of , f f,  fa, far, ...  0.059701
# 26  [hou, ous, us , s o,  of, of , f f,  fa, far, ...  0.032258
# 27  [hou, ous, us , s o,  of, of , f f,  fa, far, ...  0.101449
# 28  [hou, ous, us , s o,  of, of , f f,  fa, far, ...  0.166667
# 29  [180, 804, 04 , 4 d,  du, dua, ual, al , l s, ...  0.037736
# ..                                                ...       ...
# 70  [emb, mbe, ber, erg, rgl, glo, low, ow , w 2, ...  0.058824
# 71  [emb, mbe, ber, erg, rgl, glo, low, ow , w 2, ...  0.132353
# 72  [ame, mer, eri, ric, ica, can, an , n s,  st, ...  0.312500
# 73  [ame, mer, eri, ric, ica, can, an , n s,  st, ...  0.153846
# 74  [sum, umn, mne, ner, er , r s,  st, str, tre, ...  0.081967
# 75  [hdx, dx , x 6,  6 , 6 h,  he, hea, eav, avi, ...  0.047619
# 76  [hdx, dx , x 6,  6 , 6 h,  he, hea, eav, avi, ...  0.040000
# 77  [hdx, dx , x 6,  6 , 6 h,  he, hea, eav, avi, ...  0.208333
# 78  [qui, uik, ikr, kre, ret, et , t 8,  80, 80 , ...  0.150000
# 79  [hdx, dx , x 6,  6 , 6 h,  he, hea, eav, avi, ...  0.106383
# 80  [hdx, dx , x 6,  6 , 6 h,  he, hea, eav, avi, ...  0.051282
# 81  [hdx, dx , x 6,  6 , 6 h,  he, hea, eav, avi, ...  0.018182
# 82  [cro, row, own, wn , n b,  bo, bol, olt, lt , ...  0.163265
# 83  [cro, row, own, wn , n b,  bo, bol, olt, lt , ...  0.173913
# 84  [cro, row, own, wn , n b,  bo, bol, olt, lt , ...  0.148936
# 85  [hen, enr, nri, ri , i 5,  58, 587, 87 , 7 4, ...  0.190476
# 86  [ham, amp, mpt, pto, ton, on , n b,  ba, bay, ...  0.042857
# 87  [ham, amp, mpt, pto, ton, on , n b,  ba, bay, ...  0.100000
# 88  [ham, amp, mpt, pto, ton, on , n b,  ba, bay, ...  0.197531
# 89  [ham, amp, mpt, pto, ton, on , n b,  ba, bay, ...  0.000000
# 90  [60 , 0 x,  x , x 1,  15, 150, 50 , 0 1,  10, ...  0.190476
# 91  [sta, tan, anl, nle, ley, ey , y d,  do, doo, ...  0.112676
# 92  [sta, tan, anl, nle, ley, ey , y d,  do, doo, ...  0.191781
# 93  [sta, tan, anl, nle, ley, ey , y d,  do, doo, ...  0.140845
# 94  [moe, oen, en , n e,  es, ess, ssi, si , i s, ...  0.158416
# 95  [moe, oen, en , n e,  es, ess, ssi, si , i s, ...  0.147368
# 96  [moe, oen, en , n e,  es, ess, ssi, si , i s, ...  0.153846
# 97  [moe, oen, en , n e,  es, ess, ssi, si , i s, ...  0.170213
# 98  [moe, oen, en , n e,  es, ess, ssi, si , i s, ...  0.170213
# 99  [sta, tan, anl, nle, ley, ey , y d,  do, doo, ...  0.081081
#
# [100 rows x 11 columns]
